# %%
# !pip install beautifulsoup4
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
#NBA season we are working with
year = 2020
#Start of Advanced stats data
url = "https://www.basketball-reference.com/leagues/NBA_2020_advanced.html"
html = urlopen(url)
soup = BeautifulSoup(html)
#Get all the column headers
soup.findAll('tr', limit=2)
#Extract what we need and put it in a list
headers = [th.getText() for th in soup.findAll('tr', limit=2)[0].findAll('th')]
#Exclude first column which we do not need
headers = headers[1:]
headers
rows = soup.findAll('tr')[1:]
player_stats = [[td.getText() for td in rows[i].findAll('td')] for i in range(len(rows))]
#Start of Contract Data
url_2 = "https://www.basketball-reference.com/contracts/players.html"
html_2 = urlopen(url_2)
soup_2 = BeautifulSoup(html_2)
#Get all the column headers
soup_2.findAll('tr', limit=2)
#Extract what we need and put it in a list
headers_2 = [th.getText() for th in soup_2.findAll('tr', limit=2)[1].findAll('th')]
#Exclude first column which we do not need
headers_2 = headers_2[1:]
headers_2
rows_2 = soup_2.findAll('tr')[1:]
player_stats_2 = [[td.getText() for td in rows_2[i].findAll('td')] for i in range(len(rows_2))]
stats = pd.DataFrame(player_stats, columns = headers)
stats.head(10)
stats_2 = pd.DataFrame(player_stats_2, columns = headers_2)
stats_2.head(10)
while True:
    player = input("Please enter an NBA player or enter quit to exit: ")
    if player == "quit":
        break
    else:
        player_WS = stats['WS'][stats['Player'] == player]
        print(player_WS)
        player_salary = stats_2['2019-20'][stats_2['Player'] == player]
        print(player_salary)
# Out:
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.7/site-packages (4.8.1)
# Requirement already satisfied: soupsieve>=1.2 in /opt/conda/lib/python3.7/site-packages (from beautifulsoup4) (1.9.5)
# Please enter an NBA player or enter quit to exit: Steven Adams
# 0    1.6
# Name: WS, dtype: object
# 45    $25,842,697
# Name: 2019-20, dtype: object
# Please enter an NBA player or enter quit to exit: James Harden
# 185    4.6
# Name: WS, dtype: object
# 5    $37,800,000
# Name: 2019-20, dtype: object
# Please enter an NBA player or enter quit to exit: Stephen Curry
# 113    0.2
# Name: WS, dtype: object
# 1    $40,231,758
# Name: 2019-20, dtype: object
# Please enter an NBA player or enter quit to exit: quit

# %%
url_2 = "https://www.basketball-reference.com/contracts/players.html"
html_2 = urlopen(url_2)
soup_2 = BeautifulSoup(html_2)
#Get all the column headers
soup_2.findAll('tr', limit=2)
#Extract what we need and put it in a list
headers_2 = [th.getText() for th in soup_2.findAll('tr', limit=2)[1].findAll('th')]
#Exclude first column which we do not need
headers_2 = headers_2[1:]
headers_2
rows_2 = soup_2.findAll('tr')[1:]
player_stats_2 = [[td.getText() for td in rows_2[i].findAll('td')] for i in range(len(rows_2))]
# Out:
# [[],
#  ['Stephen Curry',
#   'GSW',
#   '$40,231,758',
#   '$43,006,362',
#   '$45,780,966',
#   '',
#   '',
#   '',
#   'Bird Rights',
#   '$129,019,086'],
#  ['Chris Paul',
#   'OKC',
#   '$38,506,482',
#   '$41,358,814',
#   '$44,211,146',
#   '',
#   '',
#   '',
#   '',
#   '$124,076,442'],
#  ['Russell Westbrook',
#   'HOU',
#   '$38,178,000',
#   '$41,006,000',
#   '$43,848,000',
#   '$46,662,000',
#   '',
#   '',
#   'Bird Rights',
#   '$123,032,000'],
#  ['John Wall',
#   'WAS',
#   '$37,800,000',
#   '$40,824,000',
#   '$43,848,000',
#   '$46,872,000',
#   '',
#   '',
#   'Bird Rights',
#   '$122,472,000'],
#  ['James Harden',
#   'HOU',
#   '$37,800,000',
#   '$40,824,000',
#   '$43,848,000',
#   '$46,872,000',
#   '',
#   '',
#   'Bird Rights',
#   '$122,472,000'],
#  ['LeBron James',
#   'LAL',
#   '$37,436,858',
#   '$39,219,565',
#   '$41,002,273',
#   '',
#   '',
#   '',
#   '',
#   '$76,656,423'],
#  ['Kevin Durant',
#   'BRK',
#   '$37,199,000',
#   '$39,058,950',
#   '$40,918,900',
#   '$42,778,850',
#   '',
#   '',
#   '',
#   '$117,176,850'],
#  ['Kemba Walker',
#   'BOS',
#   '$34,379,100',
#   '$32,742,000',
#   '$36,016,200',
#   '$37,653,300',
#   '',
#   '',
#   '',
#   '$103,137,300'],
#  ['Blake Griffin',
#   'DET',
#   '$34,234,964',
#   '$36,595,996',
#   '$38,957,028',
#   '',
#   '',
#   '',
#   'Bird Rights',
#   '$70,830,960'],
#  ['Kyle Lowry',
#   'TOR',
#   '$33,296,296',
#   '$30,000,000',
#   '',
#   '',
#   '',
#   '',
#   'Bird Rights',
#   '$63,296,296'],
#  ['Paul George',
#   'LAC',
#   '$33,005,556',
#   '$35,450,412',
#   '$37,895,268',
#   '',
#   '',
#   '',
#   'Maximum Salary',
#   '$68,455,968'],
#  ['Klay Thompson',
#   'GSW',
#   '$32,742,000',
#   '$35,361,360',
#   '$37,980,720',
#   '$40,600,080',
#   '$43,219,440',
#   '',
#   '',
#   '$189,903,600'],
#  ['Jimmy Butler',
#   'MIA',
#   '$32,742,000',
#   '$34,379,100',
#   '$36,016,200',
#   '$37,653,300',
#   '',
#   '',
#   '',
#   '$103,137,300'],
#  ['Kawhi Leonard',
#   'LAC',
#   '$32,742,000',
#   '$34,379,100',
#   '$36,016,200',
#   '',
#   '',
#   '',
#   '',
#   '$67,121,100'],
#  ['Gordon Hayward',
#   'BOS',
#   '$32,700,690',
#   '$34,187,085',
#   '',
#   '',
#   '',
#   '',
#   'Cap space',
#   '$32,700,690'],
#  ['Mike Conley',
#   'UTA',
#   '$32,511,623',
#   '$34,504,132',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$54,938,006'],
#  ['Kyrie Irving',
#   'BRK',
#   '$31,742,000',
#   '$33,329,100',
#   '$34,916,200',
#   '$36,503,300',
#   '',
#   '',
#   '',
#   '$136,490,600'],
#  ['Tobias Harris',
#   'PHI',
#   '$31,034,483',
#   '$33,517,241',
#   '$36,000,000',
#   '$38,482,759',
#   '$40,965,517',
#   '',
#   '',
#   '$180,000,000'],
#  ['Khris Middleton',
#   'MIL',
#   '$30,603,448',
#   '$33,051,724',
#   '$35,500,000',
#   '$37,948,276',
#   '$40,396,552',
#   '',
#   '',
#   '$137,103,448'],
#  ['Paul Millsap',
#   'DEN',
#   '$30,500,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap space',
#   '$30,500,000'],
#  [],
#  [],
#  ['Damian Lillard',
#   'POR',
#   '$29,802,321',
#   '$31,626,953',
#   '$43,750,000',
#   '$47,250,000',
#   '$50,750,000',
#   '$54,250,000',
#   '1st Round Pick',
#   '$257,429,274'],
#  ['Kevin Love',
#   'CLE',
#   '$28,900,000',
#   '$31,300,000',
#   '$31,300,000',
#   '$28,900,000',
#   '',
#   '',
#   'Bird Rights',
#   '$120,400,000'],
#  ['Nikola Vučević',
#   'ORL',
#   '$28,000,000',
#   '$26,000,000',
#   '$24,000,000',
#   '$22,000,000',
#   '',
#   '',
#   '',
#   '$100,000,000'],
#  ['Al Horford',
#   'PHI',
#   '$28,000,000',
#   '$27,500,000',
#   '$27,000,000',
#   '$26,500,000',
#   '',
#   '',
#   '',
#   '$97,000,000'],
#  ['DeMar DeRozan',
#   'SAS',
#   '$27,739,975',
#   '$27,739,975',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$27,739,975'],
#  ['CJ McCollum',
#   'POR',
#   '$27,556,959',
#   '$29,354,152',
#   '$30,864,198',
#   '$33,333,333',
#   '$35,802,469',
#   '',
#   '1st Round Pick',
#   '$156,911,111'],
#  ['Joel Embiid',
#   'PHI',
#   '$27,504,630',
#   '$29,542,010',
#   '$31,579,390',
#   '$33,616,770',
#   '',
#   '',
#   '1st Round Pick',
#   '$122,242,800'],
#  ['Kristaps Porziņģis',
#   'DAL',
#   '$27,285,000',
#   '$29,467,800',
#   '$31,650,600',
#   '$33,833,400',
#   '$36,016,200',
#   '',
#   '',
#   '$122,236,800'],
#  ["D'Angelo Russell",
#   'GSW',
#   '$27,285,000',
#   '$28,649,250',
#   '$30,013,500',
#   '$31,377,750',
#   '',
#   '',
#   '',
#   '$117,325,500'],
#  ['Andrew Wiggins',
#   'MIN',
#   '$27,270,000',
#   '$29,290,000',
#   '$31,310,000',
#   '$33,330,000',
#   '',
#   '',
#   '1st Round Pick',
#   '$121,200,000'],
#  ['Otto Porter',
#   'CHI',
#   '$27,250,576',
#   '$28,489,239',
#   '',
#   '',
#   '',
#   '',
#   'Bird Rights',
#   '$27,250,576'],
#  ['Devin Booker',
#   'PHO',
#   '$27,250,000',
#   '$29,430,000',
#   '$31,610,000',
#   '$33,790,000',
#   '$35,970,000',
#   '',
#   '1st round pick',
#   '$158,050,000'],
#  ['Karl-Anthony Towns',
#   'MIN',
#   '$27,250,000',
#   '$29,430,000',
#   '$31,610,000',
#   '$33,790,000',
#   '$35,970,000',
#   '',
#   '1st round pick',
#   '$155,870,000'],
#  ['Bradley Beal',
#   'WAS',
#   '$27,093,019',
#   '$28,751,775',
#   '$34,502,130',
#   '$37,262,300',
#   '',
#   '',
#   'Cap Space',
#   '$90,346,924'],
#  ['Anthony Davis',
#   'LAL',
#   '$27,093,019',
#   '$28,751,775',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$27,093,019'],
#  ['Andre Drummond',
#   'DET',
#   '$27,093,019',
#   '$28,751,775',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$27,093,019'],
#  ['Hassan Whiteside',
#   'POR',
#   '$27,093,018',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$27,093,018'],
#  ['Nikola Jokić',
#   'DEN',
#   '$26,573,595',
#   '$28,542,009',
#   '$30,510,423',
#   '$32,478,837',
#   '',
#   '',
#   '',
#   '$118,104,864'],
#  ['Jrue Holiday',
#   'NOP',
#   '$26,131,111',
#   '$26,131,111',
#   '$27,020,000',
#   '',
#   '',
#   '',
#   'Bird Rights',
#   '$52,262,222'],
#  ['LaMarcus Aldridge',
#   'SAS',
#   '$26,000,000',
#   '$24,000,000',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$50,000,000'],
#  [],
#  [],
#  ['Steven Adams',
#   'OKC',
#   '$25,842,697',
#   '$27,528,090',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$53,370,787'],
#  ['Giannis Antetokounmpo',
#   'MIL',
#   '$25,842,697',
#   '$27,528,090',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$53,370,787'],
#  ['Marc Gasol',
#   'TOR',
#   '$25,595,700',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Bird Rights',
#   '$25,595,700'],
#  ['Nicolas Batum',
#   'CHO',
#   '$25,565,217',
#   '$27,130,434',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$25,565,217'],
#  ['Chandler Parsons',
#   'ATL',
#   '$25,102,511',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$25,102,511'],
#  ['Rudy Gobert',
#   'UTA',
#   '$25,008,427',
#   '$26,525,281',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$51,533,708'],
#  ['Harrison Barnes',
#   'SAC',
#   '$24,147,727',
#   '$22,215,909',
#   '$20,284,091',
#   '$18,352,273',
#   '',
#   '',
#   '',
#   '$85,000,000'],
#  ['Serge Ibaka',
#   'TOR',
#   '$23,271,604',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap space',
#   '$23,271,604'],
#  ['Danilo Gallinari',
#   'OKC',
#   '$22,615,559',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Sign and Trade',
#   '$22,615,559'],
#  ['Victor Oladipo',
#   'IND',
#   '$21,000,000',
#   '$21,000,000',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$42,000,000'],
#  ['Malcolm Brogdon',
#   'IND',
#   '$20,000,000',
#   '$20,700,000',
#   '$21,700,000',
#   '$22,600,000',
#   '',
#   '',
#   '',
#   '$85,000,000'],
#  ['Terry Rozier',
#   'CHO',
#   '$19,894,737',
#   '$18,900,000',
#   '$17,905,263',
#   '',
#   '',
#   '',
#   '',
#   '$56,700,000'],
#  ['Aaron Gordon',
#   'ORL',
#   '$19,863,636',
#   '$18,136,364',
#   '$16,409,091',
#   '',
#   '',
#   '',
#   '',
#   '$54,409,091'],
#  ['Zach LaVine',
#   'CHI',
#   '$19,500,000',
#   '$19,500,000',
#   '$19,500,000',
#   '',
#   '',
#   '',
#   '',
#   '$58,500,000'],
#  ['Kent Bazemore',
#   'POR',
#   '$19,269,662',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$19,269,662'],
#  ['Tyler Johnson',
#   'PHO',
#   '$19,245,370',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$19,245,370'],
#  ['Goran Dragić',
#   'MIA',
#   '$19,217,900',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Bird Rights',
#   '$19,217,900'],
#  ['Jeff Teague',
#   'MIN',
#   '$19,000,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap space',
#   '$19,000,000'],
#  ['Evan Turner',
#   'ATL',
#   '$18,606,557',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$18,606,557'],
#  ['Draymond Green',
#   'GSW',
#   '$18,539,130',
#   '$22,246,956',
#   '$24,026,712',
#   '$25,806,469',
#   '$27,586,225',
#   '',
#   'Bird Rights',
#   '$90,619,267'],
#  [],
#  [],
#  ['Tristan Thompson',
#   'CLE',
#   '$18,539,130',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Bird Rights',
#   '$18,539,130'],
#  ['Allen Crabbe',
#   'ATL',
#   '$18,500,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$18,500,000'],
#  ['Tim Hardaway',
#   'DAL',
#   '$18,150,000',
#   '$18,975,000',
#   '',
#   '',
#   '',
#   '',
#   'Cap space',
#   '$18,150,000'],
#  ['Reggie Jackson',
#   'DET',
#   '$18,086,956',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Bird Rights',
#   '$18,086,956'],
#  ['Myles Turner',
#   'IND',
#   '$18,000,000',
#   '$18,000,000',
#   '$18,000,000',
#   '$18,000,000',
#   '',
#   '',
#   '1st round pick',
#   '$72,000,000'],
#  ['Julius Randle',
#   'NYK',
#   '$18,000,000',
#   '$18,900,000',
#   '$19,800,000',
#   '',
#   '',
#   '',
#   '',
#   '$40,900,000'],
#  ['Gary Harris',
#   'DEN',
#   '$17,839,286',
#   '$19,160,714',
#   '$20,482,143',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$57,482,143'],
#  ['Derrick Favors',
#   'NOP',
#   '$17,650,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$17,650,000'],
#  ['Andre Iguodala',
#   'MEM',
#   '$17,185,185',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Bird Rights',
#   '$17,185,185'],
#  ['Bojan Bogdanović',
#   'UTA',
#   '$17,000,000',
#   '$17,850,000',
#   '$18,700,000',
#   '$19,550,000',
#   '',
#   '',
#   '',
#   '$73,100,000'],
#  ['Evan Fournier',
#   'ORL',
#   '$17,000,000',
#   '$17,000,000',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$17,000,000'],
#  ['Bismack Biyombo',
#   'CHO',
#   '$17,000,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$17,000,000'],
#  ['Clint Capela',
#   'HOU',
#   '$16,456,522',
#   '$17,500,000',
#   '$18,543,478',
#   '$19,586,957',
#   '',
#   '',
#   '',
#   '$72,086,957'],
#  ['Gorgui Dieng',
#   'MIN',
#   '$16,229,213',
#   '$17,287,640',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$33,516,853'],
#  ['Ricky Rubio',
#   'PHO',
#   '$16,190,476',
#   '$17,000,000',
#   '$17,809,524',
#   '',
#   '',
#   '',
#   '',
#   '$51,000,000'],
#  ['Jonas Valančiūnas',
#   'MEM',
#   '$16,000,000',
#   '$15,000,000',
#   '$14,000,000',
#   '',
#   '',
#   '',
#   '',
#   '$45,000,000'],
#  ['Brandon Knight',
#   'CLE',
#   '$15,643,750',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$15,643,750'],
#  ['Eric Bledsoe',
#   'MIL',
#   '$15,625,000',
#   '$16,875,000',
#   '$18,125,000',
#   '$19,375,000',
#   '',
#   '',
#   'Bird Rights',
#   '$54,525,000'],
#  ['Kelly Oubre',
#   'PHO',
#   '$15,625,000',
#   '$14,375,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$30,000,000'],
#  ['Dennis Schröder',
#   'OKC',
#   '$15,500,000',
#   '$15,500,000',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$31,000,000'],
#  [],
#  [],
#  ['Ian Mahinmi',
#   'WAS',
#   '$15,450,051',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$15,450,051'],
#  ['James Johnson',
#   'MIA',
#   '$15,349,400',
#   '$16,047,100',
#   '',
#   '',
#   '',
#   '',
#   'Cap space',
#   '$15,349,400'],
#  ['Marvin Williams',
#   'CHO',
#   '$15,006,250',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$15,006,250'],
#  ['Marcus Morris',
#   'NYK',
#   '$15,000,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$15,000,000'],
#  ['Bobby Portis',
#   'NYK',
#   '$15,000,000',
#   '$15,750,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$15,000,000'],
#  ['Danny Green',
#   'LAL',
#   '$14,634,146',
#   '$15,365,854',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$30,000,000'],
#  ['Cody Zeller',
#   'CHO',
#   '$14,471,910',
#   '$15,415,730',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$29,887,640'],
#  ['Eric Gordon',
#   'HOU',
#   '$14,057,730',
#   '$16,869,276',
#   '$18,218,818',
#   '$19,568,360',
#   '$20,917,902',
#   '',
#   'Cap Space',
#   '$68,714,184'],
#  ['Mason Plumlee',
#   'DEN',
#   '$14,041,096',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap space',
#   '$14,041,096'],
#  ['Rudy Gay',
#   'SAS',
#   '$14,000,000',
#   '$14,000,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$28,000,000'],
#  ['J.J. Redick',
#   'NOP',
#   '$13,486,300',
#   '$13,013,700',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$26,500,000'],
#  ['Jordan Clarkson',
#   'CLE',
#   '$13,437,500',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$13,437,500'],
#  ['Dewayne Dedmon',
#   'SAC',
#   '$13,333,334',
#   '$13,333,333',
#   '$13,333,333',
#   '',
#   '',
#   '',
#   '',
#   '$40,000,000'],
#  ['Solomon Hill',
#   'MEM',
#   '$13,258,781',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$13,258,781'],
#  ['Justise Winslow',
#   'MIA',
#   '$13,000,000',
#   '$13,000,000',
#   '$13,000,000',
#   '',
#   '',
#   '',
#   '1st round pick',
#   '$26,000,000'],
#  ['Michael Kidd-Gilchrist',
#   'CHO',
#   '$13,000,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$13,000,000'],
#  ['Will Barton',
#   'DEN',
#   '$12,960,000',
#   '$13,920,000',
#   '$14,880,000',
#   '',
#   '',
#   '',
#   '',
#   '$26,880,000'],
#  ['Thaddeus Young',
#   'CHI',
#   '$12,900,000',
#   '$13,545,000',
#   '$14,190,000',
#   '',
#   '',
#   '',
#   '',
#   '$32,445,000'],
#  ['Courtney Lee',
#   'DAL',
#   '$12,759,670',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$12,759,670'],
#  ['Larry Nance',
#   'CLE',
#   '$12,727,273',
#   '$11,709,091',
#   '$10,690,909',
#   '$9,672,727',
#   '',
#   '',
#   '1st Round pick',
#   '$44,800,000'],
#  [],
#  [],
#  ['Marcus Smart',
#   'BOS',
#   '$12,553,471',
#   '$13,446,428',
#   '$14,339,285',
#   '',
#   '',
#   '',
#   '',
#   '$40,339,184'],
#  ['Terrence Ross',
#   'ORL',
#   '$12,500,000',
#   '$13,500,000',
#   '$12,500,000',
#   '$11,500,000',
#   '',
#   '',
#   '',
#   '$50,000,000'],
#  ['Miles Plumlee',
#   'MEM',
#   '$12,500,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$12,500,000'],
#  ['Patty Mills',
#   'SAS',
#   '$12,428,571',
#   '$13,285,714',
#   '',
#   '',
#   '',
#   '',
#   'Bird Rights',
#   '$25,714,285'],
#  ['Patrick Beverley',
#   'LAC',
#   '$12,345,679',
#   '$13,333,333',
#   '$14,320,988',
#   '',
#   '',
#   '',
#   '',
#   '$40,000,000'],
#  ['Trevor Ariza',
#   'SAC',
#   '$12,200,000',
#   '$12,800,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$14,000,000'],
#  ['Dion Waiters',
#   'MIA',
#   '$12,100,000',
#   '$12,650,000',
#   '',
#   '',
#   '',
#   '',
#   'Cap space',
#   '$24,750,000'],
#  ['Brook Lopez',
#   'MIL',
#   '$12,093,024',
#   '$12,697,675',
#   '$13,302,325',
#   '$13,906,976',
#   '',
#   '',
#   '',
#   '$52,000,000'],
#  ['Jusuf Nurkić',
#   'POR',
#   '$12,000,000',
#   '$12,000,000',
#   '$12,000,000',
#   '',
#   '',
#   '',
#   '',
#   '$28,000,000'],
#  ['Cory Joseph',
#   'SAC',
#   '$12,000,000',
#   '$12,600,000',
#   '$12,600,000',
#   '',
#   '',
#   '',
#   '',
#   '$24,600,000'],
#  ['Joe Ingles',
#   'UTA',
#   '$11,954,546',
#   '$10,863,637',
#   '$14,000,000',
#   '',
#   '',
#   '',
#   'Bird Rights',
#   '$36,818,183'],
#  ['Kelly Olynyk',
#   'MIA',
#   '$11,667,885',
#   '$12,198,243',
#   '',
#   '',
#   '',
#   '',
#   'Cap space',
#   '$11,667,885'],
#  ['Maurice Harkless',
#   'LAC',
#   '$11,511,234',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$11,511,234'],
#  ['Tony Snell',
#   'DET',
#   '$11,392,857',
#   '$12,178,571',
#   '',
#   '',
#   '',
#   '',
#   'Cap space',
#   '$11,392,857'],
#  ['Robert Covington',
#   'MIN',
#   '$11,301,219',
#   '$12,138,345',
#   '$12,975,471',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$36,415,035'],
#  ['Meyers Leonard',
#   'MIA',
#   '$11,286,515',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$11,286,515'],
#  ['T.J. Warren',
#   'IND',
#   '$10,810,000',
#   '$11,750,000',
#   '$12,690,000',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$35,250,000'],
#  ['Andre Roberson',
#   'OKC',
#   '$10,740,741',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Bird Rights',
#   '$10,740,741'],
#  ['Spencer Dinwiddie',
#   'BRK',
#   '$10,600,000',
#   '$11,400,000',
#   '$12,300,000',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$22,000,000'],
#  ['Jeremy Lamb',
#   'IND',
#   '$10,500,000',
#   '$10,500,000',
#   '$10,500,000',
#   '',
#   '',
#   '',
#   '',
#   '$31,500,000'],
#  [],
#  [],
#  ['Dwight Powell',
#   'DAL',
#   '$10,259,375',
#   '$10,185,185',
#   '$11,000,000',
#   '$11,814,815',
#   '',
#   '',
#   'Cap Space',
#   '$43,259,375'],
#  ['Norman Powell',
#   'TOR',
#   '$10,116,576',
#   '$10,865,952',
#   '$11,615,328',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$20,982,528'],
#  ['Josh Richardson',
#   'PHI',
#   '$10,100,000',
#   '$10,800,000',
#   '$11,600,000',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$20,900,000'],
#  ['Tomáš Satoranský',
#   'CHI',
#   '$10,000,000',
#   '$10,000,000',
#   '$10,000,000',
#   '',
#   '',
#   '',
#   '',
#   '$25,000,000'],
#  ['DeAndre Jordan',
#   'BRK',
#   '$9,881,598',
#   '$10,375,678',
#   '$9,881,598',
#   '$9,821,842',
#   '',
#   '',
#   '',
#   '$39,960,716'],
#  ['Taj Gibson',
#   'NYK',
#   '$9,800,000',
#   '$10,290,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$9,800,000'],
#  ['Zion Williamson',
#   'NOP',
#   '$9,757,440',
#   '$10,245,480',
#   '$10,733,400',
#   '$13,534,817',
#   '',
#   '',
#   '1st Round Pick',
#   '$20,002,920'],
#  ['Markelle Fultz',
#   'ORL',
#   '$9,745,200',
#   '$12,288,697',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$22,033,897'],
#  ['John Henson',
#   'CLE',
#   '$9,732,396',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$9,732,396'],
#  ['Matthew Dellavedova',
#   'CLE',
#   '$9,607,500',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$9,607,500'],
#  ['Dante Exum',
#   'UTA',
#   '$9,600,000',
#   '$9,600,000',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$18,200,000'],
#  ['Deandre Ayton',
#   'PHO',
#   '$9,562,920',
#   '$10,018,200',
#   '$12,632,950',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$19,581,120'],
#  ['Delon Wright',
#   'DAL',
#   '$9,473,684',
#   '$9,000,000',
#   '$8,526,316',
#   '',
#   '',
#   '',
#   '',
#   '$27,000,000'],
#  ['Jerami Grant',
#   'DEN',
#   '$9,346,153',
#   '$9,346,153',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$9,346,153'],
#  ['Al-Farouq Aminu',
#   'ORL',
#   '$9,258,000',
#   '$9,720,900',
#   '$10,183,800',
#   '',
#   '',
#   '',
#   'MLE',
#   '$29,162,700'],
#  ['George Hill',
#   'MIL',
#   '$9,133,907',
#   '$9,590,602',
#   '$10,047,297',
#   '',
#   '',
#   '',
#   '',
#   '$21,000,000'],
#  ['Kyle Anderson',
#   'MEM',
#   '$9,073,050',
#   '$9,505,100',
#   '$9,937,150',
#   '',
#   '',
#   '',
#   'MLE',
#   '$28,515,300'],
#  ['Fred VanVleet',
#   'TOR',
#   '$9,000,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Bird Rights',
#   '$9,000,000'],
#  ['Ja Morant',
#   'MEM',
#   '$8,730,240',
#   '$9,166,800',
#   '$9,603,360',
#   '$12,119,440',
#   '',
#   '',
#   '1st Round Pick',
#   '$17,897,040'],
#  ['C.J. Miles', 'WAS', '$8,730,158', '', '', '', '', '', 'MLE', '$8,730,158'],
#  [],
#  [],
#  ['Lonzo Ball',
#   'NOP',
#   '$8,719,320',
#   '$11,003,782',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$19,723,102'],
#  ["E'Twaun Moore",
#   'NOP',
#   '$8,664,928',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$8,664,928'],
#  ['Marvin Bagley',
#   'SAC',
#   '$8,556,120',
#   '$8,963,640',
#   '$11,312,114',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$17,519,760'],
#  ['Bogdan Bogdanović',
#   'SAC',
#   '$8,529,386',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap space',
#   '$8,529,386'],
#  ['Tyus Jones',
#   'MEM',
#   '$8,408,000',
#   '$7,965,100',
#   '$7,522,200',
#   '',
#   '',
#   '',
#   'MLE',
#   '$23,895,300'],
#  ['P.J. Tucker',
#   'HOU',
#   '$8,349,039',
#   '$7,969,537',
#   '',
#   '',
#   '',
#   '',
#   'MLE',
#   '$10,918,227'],
#  ['Cristiano Felício',
#   'CHI',
#   '$8,156,500',
#   '$7,529,020',
#   '',
#   '',
#   '',
#   '',
#   'Cap space',
#   '$15,685,520'],
#  ['Ben Simmons',
#   'PHI',
#   '$8,113,930',
#   '$29,250,000',
#   '$31,590,000',
#   '$33,930,000',
#   '$36,270,000',
#   '$38,610,000',
#   '1st Round pick',
#   '$177,763,930'],
#  ['Kentavious Caldwell-Pope',
#   'LAL',
#   '$8,089,282',
#   '$8,493,746',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$8,089,282'],
#  ['Maxi Kleber',
#   'DAL',
#   '$8,000,000',
#   '$8,250,000',
#   '$8,750,000',
#   '$9,000,000',
#   '',
#   '',
#   '',
#   '$25,000,000'],
#  ['Lou Williams',
#   'LAC',
#   '$8,000,000',
#   '$8,000,000',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$16,000,000'],
#  ['Elfrid Payton',
#   'NYK',
#   '$8,000,000',
#   '$8,000,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$9,000,000'],
#  ['Thomas Bryant',
#   'WAS',
#   '$7,936,508',
#   '$8,333,333',
#   '$8,730,159',
#   '',
#   '',
#   '',
#   '',
#   '$25,000,000'],
#  ['RJ Barrett',
#   'NYK',
#   '$7,839,960',
#   '$8,231,760',
#   '$8,623,920',
#   '$10,900,635',
#   '',
#   '',
#   '1st Round Pick',
#   '$16,071,720'],
#  ['Jayson Tatum',
#   'BOS',
#   '$7,830,000',
#   '$9,897,120',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$17,727,120'],
#  ['Jae Crowder',
#   'MEM',
#   '$7,815,533',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Bird Rights',
#   '$7,815,533'],
#  ['Wayne Ellington',
#   'NYK',
#   '$7,804,878',
#   '$8,195,122',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$7,804,878'],
#  ['Luka Dončić',
#   'DAL',
#   '$7,683,360',
#   '$8,049,360',
#   '$10,174,391',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$15,732,720'],
#  ['Joe Harris',
#   'BRK',
#   '$7,670,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Early Bird Rights',
#   '$7,670,000'],
#  ['Seth Curry',
#   'DAL',
#   '$7,441,860',
#   '$7,813,953',
#   '$8,186,047',
#   '$8,558,140',
#   '',
#   '',
#   'MLE',
#   '$32,000,000'],
#  [],
#  [],
#  ['Doug McDermott',
#   'IND',
#   '$7,333,334',
#   '$7,333,333',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$14,666,667'],
#  ['Langston Galloway',
#   'DET',
#   '$7,333,333',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'MLE',
#   '$7,333,333'],
#  ['Derrick Rose',
#   'DET',
#   '$7,317,073',
#   '$7,682,927',
#   '',
#   '',
#   '',
#   '',
#   'MLE',
#   '$15,000,000'],
#  ['Brandon Ingram',
#   'NOP',
#   '$7,265,485',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '1st Round pick',
#   '$7,265,485'],
#  ['D.J. Augustin',
#   'ORL',
#   '$7,250,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$7,250,000'],
#  ['Darius Miller',
#   'NOP',
#   '$7,250,000',
#   '$7,000,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$7,250,000'],
#  ["De'Andre Hunter",
#   'ATL',
#   '$7,068,360',
#   '$7,422,000',
#   '$7,775,400',
#   '$9,835,881',
#   '',
#   '',
#   '1st Round Pick',
#   '$14,490,360'],
#  ['Josh Jackson',
#   'MEM',
#   '$7,059,480',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$7,059,480'],
#  ['DeMarre Carroll',
#   'SAS',
#   '$7,000,000',
#   '$6,650,000',
#   '$7,000,000',
#   '',
#   '',
#   '',
#   '',
#   '$15,000,000'],
#  ['Dāvis Bertāns',
#   'WAS',
#   '$7,000,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Early Bird Rights',
#   '$7,000,000'],
#  ['Ersan İlyasova',
#   'MIL',
#   '$7,000,000',
#   '$7,000,000',
#   '',
#   '',
#   '',
#   '',
#   'MLE',
#   '$7,000,000'],
#  ['Jaren Jackson',
#   'MEM',
#   '$6,927,480',
#   '$7,257,360',
#   '$9,180,560',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$14,184,840'],
#  ['Nemanja Bjelica',
#   'SAC',
#   '$6,825,000',
#   '$7,150,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$6,825,000'],
#  ['Jaylen Brown',
#   'BOS',
#   '$6,534,829',
#   '$22,991,071',
#   '$24,830,357',
#   '$26,669,643',
#   '$28,508,929',
#   '',
#   '1st Rd pick',
#   '$109,534,829'],
#  ['Jabari Parker',
#   'ATL',
#   '$6,500,000',
#   '$6,500,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$6,500,000'],
#  ['Ivica Zubac',
#   'LAC',
#   '$6,481,482',
#   '$7,000,000',
#   '$7,518,518',
#   '$7,518,518',
#   '',
#   '',
#   '',
#   '$21,000,000'],
#  ['Joakim Noah',
#   'NYK',
#   '$6,431,666',
#   '$6,431,666',
#   '$6,431,666',
#   '',
#   '',
#   '',
#   '',
#   '$19,294,998'],
#  ['Darius Garland',
#   'CLE',
#   '$6,400,920',
#   '$6,720,720',
#   '$7,040,880',
#   '$8,920,795',
#   '',
#   '',
#   '1st Round Pick',
#   '$13,121,640'],
#  ["De'Aaron Fox",
#   'SAC',
#   '$6,392,760',
#   '$8,099,627',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$14,492,387'],
#  ['Trae Young',
#   'ATL',
#   '$6,273,000',
#   '$6,571,800',
#   '$8,326,471',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$12,844,800'],
#  [],
#  [],
#  ['Montrezl Harrell',
#   'LAC',
#   '$6,000,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$6,000,000'],
#  ['Ish Smith',
#   'WAS',
#   '$5,853,659',
#   '$6,146,341',
#   '',
#   '',
#   '',
#   '',
#   'MLE',
#   '$12,000,000'],
#  ['Marco Belinelli',
#   'SAS',
#   '$5,846,154',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'MLE',
#   '$5,846,154'],
#  ['Jarrett Culver',
#   'MIN',
#   '$5,813,640',
#   '$6,104,280',
#   '$6,395,160',
#   '$8,109,063',
#   '',
#   '',
#   '1st Round Pick',
#   '$11,917,920'],
#  ['Jonathan Isaac',
#   'ORL',
#   '$5,806,440',
#   '$7,362,566',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$13,169,006'],
#  ['Rodney Hood',
#   'POR',
#   '$5,718,000',
#   '$6,003,900',
#   '',
#   '',
#   '',
#   '',
#   'MLE',
#   '$5,718,000'],
#  ['Mo Bamba',
#   'ORL',
#   '$5,697,600',
#   '$5,969,040',
#   '$7,568,742',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$11,666,640'],
#  ['Timofey Mozgov',
#   'ORL',
#   '$5,573,333',
#   '$5,573,333',
#   '$5,573,334',
#   '',
#   '',
#   '',
#   '',
#   '$16,720,000'],
#  ['Trey Lyles',
#   'SAS',
#   '$5,500,000',
#   '$5,500,000',
#   '',
#   '',
#   '',
#   '',
#   'MLE',
#   '$5,500,000'],
#  ['Deron Williams', 'BRK', '$5,474,787', '', '', '', '', '', '', '$5,474,787'],
#  ['Aron Baynes', 'PHO', '$5,453,280', '', '', '', '', '', '', '$5,453,280'],
#  ['Kris Dunn',
#   'CHI',
#   '$5,348,007',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '1st Round pick',
#   '$5,348,007'],
#  ['Josh Smith', 'DET', '$5,331,729', '', '', '', '', '', '', '$5,331,729'],
#  ['Coby White',
#   'CHI',
#   '$5,307,120',
#   '$5,572,680',
#   '$5,837,760',
#   '$7,413,955',
#   '',
#   '',
#   '1st Round Pick',
#   '$10,879,800'],
#  ['Lauri Markkanen',
#   'CHI',
#   '$5,300,400',
#   '$6,731,508',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$12,031,908'],
#  ['Ryan Anderson',
#   'MIA',
#   '$5,214,583',
#   '$5,214,583',
#   '$5,214,584',
#   '',
#   '',
#   '',
#   '',
#   '$15,643,750'],
#  ['Wendell Carter',
#   'CHI',
#   '$5,201,400',
#   '$5,448,840',
#   '$6,920,027',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$10,650,240'],
#  ['Pau Gasol', 'SAS', '$5,100,000', '', '', '', '', '', '', '$5,100,000'],
#  ['Daniel Theis',
#   'BOS',
#   '$5,000,000',
#   '$5,000,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$5,000,000'],
#  ['Luol Deng',
#   'LAL',
#   '$4,990,000',
#   '$4,990,000',
#   '$4,990,000',
#   '',
#   '',
#   '',
#   '',
#   '$14,970,000'],
#  [],
#  [],
#  ['Jaxson Hayes',
#   'NOP',
#   '$4,862,040',
#   '$5,105,160',
#   '$5,348,280',
#   '$6,803,012',
#   '',
#   '',
#   '1st Round Pick',
#   '$9,967,200'],
#  ['Buddy Hield',
#   'SAC',
#   '$4,861,208',
#   '$24,431,818',
#   '$22,477,273',
#   '$20,522,727',
#   '$18,568,182',
#   '',
#   '1st Round pick',
#   '$90,861,208'],
#  ['Frank Ntilikina',
#   'NYK',
#   '$4,855,800',
#   '$6,176,578',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$11,032,378'],
#  ['Ed Davis',
#   'UTA',
#   '$4,767,000',
#   '$5,005,350',
#   '',
#   '',
#   '',
#   '',
#   'Room Exception',
#   '$9,772,350'],
#  ['Richaun Holmes',
#   'SAC',
#   '$4,767,000',
#   '$5,005,350',
#   '',
#   '',
#   '',
#   '',
#   'Room Exception',
#   '$9,772,350'],
#  ['Frank Kaminsky',
#   'PHO',
#   '$4,767,000',
#   '$5,005,350',
#   '',
#   '',
#   '',
#   '',
#   'Room Exception',
#   '$9,772,350'],
#  ['Mike Scott',
#   'PHI',
#   '$4,767,000',
#   '$5,005,350',
#   '',
#   '',
#   '',
#   '',
#   'Room Exception',
#   '$9,772,350'],
#  ['Avery Bradley',
#   'LAL',
#   '$4,767,000',
#   '$5,005,350',
#   '',
#   '',
#   '',
#   '',
#   'Room Exception',
#   '$9,772,350'],
#  ['Robin Lopez',
#   'MIL',
#   '$4,767,000',
#   '$5,005,350',
#   '',
#   '',
#   '',
#   '',
#   'Room Exception',
#   '$4,767,000'],
#  ['JaMychal Green',
#   'LAC',
#   '$4,767,000',
#   '$5,005,350',
#   '',
#   '',
#   '',
#   '',
#   'Room Exception',
#   '$4,767,000'],
#  ['Justin Holiday',
#   'IND',
#   '$4,767,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Room Exception',
#   '$4,767,000'],
#  ['Garrett Temple',
#   'BRK',
#   '$4,767,000',
#   '$5,005,350',
#   '',
#   '',
#   '',
#   '',
#   'Room Exception',
#   '$4,767,000'],
#  ['Enes Kanter',
#   'BOS',
#   '$4,767,000',
#   '$5,005,350',
#   '',
#   '',
#   '',
#   '',
#   'Room Exception',
#   '$4,767,000'],
#  ['Collin Sexton',
#   'CLE',
#   '$4,764,960',
#   '$4,991,880',
#   '$6,349,671',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$9,756,840'],
#  ['Rodney McGruder',
#   'LAC',
#   '$4,629,630',
#   '$5,000,000',
#   '$5,370,370',
#   '',
#   '',
#   '',
#   '',
#   '$15,000,000'],
#  ['Kevon Looney',
#   'GSW',
#   '$4,629,630',
#   '$5,000,000',
#   '$5,370,370',
#   '',
#   '',
#   '',
#   '',
#   '$9,629,630'],
#  ['Rui Hachimura',
#   'WAS',
#   '$4,469,160',
#   '$4,692,840',
#   '$4,916,160',
#   '$6,263,188',
#   '',
#   '',
#   '1st Round Pick',
#   '$9,162,000'],
#  ['Dennis Smith',
#   'NYK',
#   '$4,463,640',
#   '$5,686,677',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$10,150,317'],
#  ['Jamal Murray',
#   'DEN',
#   '$4,444,746',
#   '$29,250,000',
#   '$31,590,000',
#   '$33,930,000',
#   '$36,270,000',
#   '$38,610,000',
#   '1st Round pick',
#   '$174,094,746'],
#  ['Kevin Knox',
#   'NYK',
#   '$4,380,120',
#   '$4,588,680',
#   '$5,845,978',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$8,968,800'],
#  [],
#  [],
#  ['Cam Reddish',
#   'ATL',
#   '$4,245,720',
#   '$4,458,000',
#   '$4,670,160',
#   '$5,954,454',
#   '',
#   '',
#   '1st Round Pick',
#   '$8,703,720'],
#  ['Zach Collins',
#   'POR',
#   '$4,240,200',
#   '$5,406,255',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$9,646,455'],
#  ['Mikal Bridges',
#   'PHO',
#   '$4,161,000',
#   '$4,359,000',
#   '$5,557,725',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$8,520,000'],
#  ['Alex Len',
#   'ATL',
#   '$4,160,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Room Exception',
#   '$4,160,000'],
#  ['Cameron Johnson',
#   'PHO',
#   '$4,033,440',
#   '$4,235,160',
#   '$4,437,000',
#   '$5,887,899',
#   '',
#   '',
#   '1st Round Pick',
#   '$8,268,600'],
#  ['Malik Monk',
#   'CHO',
#   '$4,028,400',
#   '$5,345,687',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$9,374,087'],
#  ['Dorian Finney-Smith',
#   'DAL',
#   '$4,000,000',
#   '$4,000,000',
#   '$4,000,000',
#   '',
#   '',
#   '',
#   '',
#   '$12,000,000'],
#  ['JaVale McGee',
#   'LAL',
#   '$4,000,000',
#   '$4,200,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$8,200,000'],
#  ['Patrick McCaw',
#   'TOR',
#   '$4,000,000',
#   '$4,000,000',
#   '',
#   '',
#   '',
#   '',
#   'MLE',
#   '$8,000,000'],
#  ['Reggie Bullock',
#   'NYK',
#   '$4,000,000',
#   '$4,200,000',
#   '',
#   '',
#   '',
#   '',
#   'Room Exception',
#   '$5,000,000'],
#  ['Shai Gilgeous-Alexander',
#   'OKC',
#   '$3,952,920',
#   '$4,141,320',
#   '$5,495,532',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$8,094,240'],
#  ['Nicolò Melli',
#   'NOP',
#   '$3,902,439',
#   '$4,097,561',
#   '',
#   '',
#   '',
#   '',
#   'Room Exception',
#   '$8,000,000'],
#  ['PJ Washington',
#   'CHO',
#   '$3,831,840',
#   '$4,023,600',
#   '$4,215,120',
#   '$5,808,435',
#   '',
#   '',
#   '1st Round Pick',
#   '$7,855,440'],
#  ['Luke Kennard',
#   'DET',
#   '$3,827,160',
#   '$5,273,826',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$9,100,986'],
#  ['Miles Bridges',
#   'CHO',
#   '$3,755,400',
#   '$3,934,320',
#   '$5,421,493',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$7,689,720'],
#  ['Jakob Pöltl',
#   'SAS',
#   '$3,754,886',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '1st Round pick',
#   '$3,754,886'],
#  ['Tyler Herro',
#   'MIA',
#   '$3,640,200',
#   '$3,822,240',
#   '$4,004,280',
#   '$5,722,116',
#   '',
#   '',
#   '1st Round Pick',
#   '$7,462,440'],
#  ['Donovan Mitchell',
#   'UTA',
#   '$3,635,760',
#   '$5,195,501',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$8,831,261'],
#  ['Stanley Johnson',
#   'TOR',
#   '$3,623,000',
#   '$3,801,000',
#   '',
#   '',
#   '',
#   '',
#   'Bi-annual Exception',
#   '$3,623,000'],
#  ['Jake Layman',
#   'MIN',
#   '$3,581,986',
#   '$3,761,085',
#   '$3,940,184',
#   '',
#   '',
#   '',
#   '',
#   '$11,283,255'],
#  [],
#  [],
#  ['Thon Maker',
#   'DET',
#   '$3,569,643',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '1st Round pick',
#   '$3,569,643'],
#  ['Jerome Robinson',
#   'LAC',
#   '$3,567,720',
#   '$3,737,520',
#   '$5,340,916',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$7,305,240'],
#  ['Allonzo Trier',
#   'NYK',
#   '$3,551,100',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Bi-Annual Exception',
#   '$3,551,100'],
#  ['Danuel House',
#   'HOU',
#   '$3,540,000',
#   '$3,717,000',
#   '$3,894,000',
#   '',
#   '',
#   '',
#   'MLE',
#   '$11,151,000'],
#  ['Domantas Sabonis',
#   'IND',
#   '$3,529,555',
#   '$17,187,500',
#   '$18,562,500',
#   '$19,937,500',
#   '$21,312,500',
#   '',
#   '1st Round pick',
#   '$80,529,555'],
#  ['Mirza Teletović',
#   'MIL',
#   '$3,500,000',
#   '$3,500,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$7,000,000'],
#  ['Boban Marjanović',
#   'DAL',
#   '$3,500,000',
#   '$3,500,000',
#   '',
#   '',
#   '',
#   '',
#   'Bi-Annual Exception',
#   '$7,000,000'],
#  ['T.J. McConnell',
#   'IND',
#   '$3,500,000',
#   '$3,500,000',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$4,500,000'],
#  ['DeMarcus Cousins',
#   'LAL',
#   '$3,500,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$3,500,000'],
#  ['Taurean Waller-Prince',
#   'BRK',
#   '$3,481,986',
#   '$13,942,308',
#   '$15,057,692',
#   '',
#   '',
#   '',
#   '1st Round pick',
#   '$32,481,986'],
#  ['Dario Šarić',
#   'PHO',
#   '$3,481,986',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '1st Round pick',
#   '$3,481,986'],
#  ['Romeo Langford',
#   'BOS',
#   '$3,458,400',
#   '$3,631,200',
#   '$3,804,360',
#   '$5,634,257',
#   '',
#   '',
#   '1st Round Pick',
#   '$7,089,600'],
#  ['Bam Adebayo',
#   'MIA',
#   '$3,454,080',
#   '$5,115,492',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$8,569,572'],
#  ['Kyle Korver', 'PHO', '$3,440,000', '', '', '', '', '', '', '$3,440,000'],
#  ['Michael Porter',
#   'DEN',
#   '$3,389,400',
#   '$3,550,800',
#   '$5,258,735',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$6,940,200'],
#  ['Denzel Valentine',
#   'CHI',
#   '$3,377,569',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '1st Round pick',
#   '$3,377,569'],
#  ['Juan Hernangómez',
#   'DEN',
#   '$3,321,030',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '1st Round pick',
#   '$3,321,030'],
#  ['Sekou Doumbouya',
#   'DET',
#   '$3,285,120',
#   '$3,449,400',
#   '$3,613,680',
#   '$5,539,771',
#   '',
#   '',
#   '1st Round Pick',
#   '$6,734,520'],
#  ['Justin Jackson',
#   'DAL',
#   '$3,280,920',
#   '$5,029,650',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$8,310,570'],
#  ['Troy Brown',
#   'WAS',
#   '$3,219,480',
#   '$3,372,840',
#   '$5,170,564',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$6,592,320'],
#  [],
#  [],
#  ['Markieff Morris',
#   'DET',
#   '$3,200,000',
#   '$3,360,000',
#   '',
#   '',
#   '',
#   '',
#   'Bi-annual Exception',
#   '$3,200,000'],
#  ['Jon Leuer',
#   'MIL',
#   '$3,169,348',
#   '$3,169,348',
#   '$3,169,347',
#   '',
#   '',
#   '',
#   '',
#   '$9,508,043'],
#  ['Yogi Ferrell',
#   'SAC',
#   '$3,150,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$3,150,000'],
#  ['Guerschon Yabusele',
#   'BOS',
#   '$3,117,240',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$3,117,240'],
#  ['Zhaire Smith',
#   'PHI',
#   '$3,058,800',
#   '$3,204,600',
#   '$4,915,856',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$6,263,400'],
#  ['Dwight Howard', 'MEM', '$3,039,097', '', '', '', '', '', '', '$3,039,097'],
#  ['Khem Birch',
#   'ORL',
#   '$3,000,000',
#   '$3,000,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$6,000,000'],
#  ['Ryan Arcidiacono',
#   'CHI',
#   '$3,000,000',
#   '$3,000,000',
#   '$3,000,000',
#   '',
#   '',
#   '',
#   '',
#   '$6,000,000'],
#  ['Quinn Cook',
#   'LAL',
#   '$3,000,000',
#   '$3,000,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$4,000,000'],
#  ['Ömer Aşık', 'CHI', '$3,000,000', '', '', '', '', '', '', '$3,000,000'],
#  ['Nickeil Alexander-Walker',
#   'NOP',
#   '$2,964,840',
#   '$3,113,160',
#   '$3,261,480',
#   '$5,009,633',
#   '',
#   '',
#   '1st Round Pick',
#   '$6,078,000'],
#  ['D.J. Wilson',
#   'MIL',
#   '$2,961,120',
#   '$4,548,280',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$7,509,400'],
#  ['Cedi Osman',
#   'CLE',
#   '$2,907,143',
#   '$8,750,000',
#   '$8,050,000',
#   '$7,350,000',
#   '$6,650,000',
#   '',
#   'MLE',
#   '$27,057,143'],
#  ['Donte DiVincenzo',
#   'MIL',
#   '$2,905,800',
#   '$3,044,160',
#   '$4,675,830',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$5,949,960'],
#  ['Bryn Forbes',
#   'SAS',
#   '$2,875,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Early Bird Rights',
#   '$2,875,000'],
#  ['Andrew Nicholson',
#   'POR',
#   '$2,844,429',
#   '$2,844,429',
#   '$2,844,429',
#   '$2,844,429',
#   '$2,844,429',
#   '',
#   '',
#   '$14,222,145'],
#  ['Goga Bitadze',
#   'IND',
#   '$2,816,760',
#   '$2,957,520',
#   '$3,098,400',
#   '$4,765,339',
#   '',
#   '',
#   '1st Round Pick',
#   '$5,774,280'],
#  ['T.J. Leaf',
#   'IND',
#   '$2,813,280',
#   '$4,326,825',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$7,140,105'],
#  ['Lonnie Walker',
#   'SAS',
#   '$2,760,480',
#   '$2,892,000',
#   '$4,447,896',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$5,652,480'],
#  ['Alex Caruso',
#   'LAL',
#   '$2,750,000',
#   '$2,750,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$5,500,000'],
#  [],
#  [],
#  ['Malik Beasley',
#   'DEN',
#   '$2,731,714',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '1st Round pick',
#   '$2,731,714'],
#  ['Luka Šamanić',
#   'SAS',
#   '$2,689,920',
#   '$2,824,320',
#   '$2,959,080',
#   '$4,556,983',
#   '',
#   '',
#   '1st Round Pick',
#   '$5,514,240'],
#  ['John Collins',
#   'ATL',
#   '$2,686,560',
#   '$4,137,302',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$6,823,862'],
#  ['Kevin Huerter',
#   'ATL',
#   '$2,636,280',
#   '$2,761,920',
#   '$4,253,357',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$5,398,200'],
#  ['Caris LeVert',
#   'BRK',
#   '$2,625,718',
#   '$16,203,704',
#   '$17,500,000',
#   '$18,796,296',
#   '',
#   '',
#   '1st Round pick',
#   '$55,125,718'],
#  ['Marko Guduric',
#   'MEM',
#   '$2,625,000',
#   '$2,750,000',
#   '',
#   '',
#   '',
#   '',
#   'Bi-annual Exception',
#   '$5,375,000'],
#  ["DeAndre' Bembry",
#   'ATL',
#   '$2,603,982',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '1st Round pick',
#   '$2,603,982'],
#  ['Matisse Thybulle',
#   'PHI',
#   '$2,582,160',
#   '$2,711,280',
#   '$2,840,160',
#   '$4,379,527',
#   '',
#   '',
#   '1st Round Pick',
#   '$5,293,440'],
#  ['Harry Giles',
#   'SAC',
#   '$2,578,800',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$2,578,800'],
#  ['Jeff Green',
#   'UTA',
#   '$2,564,753',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$2,564,753'],
#  ['Pau Gasol', 'POR', '$2,564,753', '', '', '', '', '', '', '$2,564,753'],
#  ['Anthony Tolliver',
#   'POR',
#   '$2,564,753',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$2,564,753'],
#  ['Wesley Matthews',
#   'MIL',
#   '$2,564,753',
#   '$2,692,991',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$2,564,753'],
#  ['Kyle Korver',
#   'MIL',
#   '$2,564,753',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$2,564,753'],
#  ['Udonis Haslem',
#   'MIA',
#   '$2,564,753',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$2,564,753'],
#  ['Jared Dudley',
#   'LAL',
#   '$2,564,753',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$2,564,753'],
#  ['Rajon Rondo',
#   'LAL',
#   '$2,564,753',
#   '$2,619,605',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$2,564,753'],
#  ['Tyson Chandler',
#   'HOU',
#   '$2,564,753',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$2,564,753'],
#  ['Gerald Green',
#   'HOU',
#   '$2,564,753',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$2,564,753'],
#  ['Thabo Sefolosha',
#   'HOU',
#   '$2,564,753',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$2,564,753'],
#  [],
#  [],
#  ['Nenê Hilário',
#   'HOU',
#   '$2,564,753',
#   '$2,692,991',
#   '',
#   '',
#   '',
#   '',
#   'Bird Rights',
#   '$2,564,753'],
#  ['J.J. Barea',
#   'DAL',
#   '$2,564,753',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$2,564,753'],
#  ['Wilson Chandler',
#   'BRK',
#   '$2,564,753',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$2,564,753'],
#  ['Vince Carter',
#   'ATL',
#   '$2,564,753',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$2,564,753'],
#  ['Dwight Howard', 'LAL', '$2,564,753', '', '', '', '', '', '', ''],
#  ['Josh Okogie',
#   'MIN',
#   '$2,530,680',
#   '$2,651,040',
#   '$4,087,904',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$5,181,720'],
#  ['Vincent Poirier',
#   'BOS',
#   '$2,505,793',
#   '$2,619,207',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$5,125,000'],
#  ['Rondae Hollis-Jefferson',
#   'TOR',
#   '$2,500,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'MLE',
#   '$2,500,000'],
#  ['Brandon Clarke',
#   'MEM',
#   '$2,478,840',
#   '$2,602,920',
#   '$2,726,880',
#   '$4,343,920',
#   '',
#   '',
#   '1st Round Pick',
#   '$5,081,760'],
#  ['Terrance Ferguson',
#   'OKC',
#   '$2,475,840',
#   '$3,944,013',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$6,419,853'],
#  ['Grayson Allen',
#   'MEM',
#   '$2,429,400',
#   '$2,545,320',
#   '$4,054,695',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$4,974,720'],
#  ['Grant Williams',
#   'BOS',
#   '$2,379,840',
#   '$2,498,760',
#   '$2,617,800',
#   '$4,306,281',
#   '',
#   '',
#   '1st Round Pick',
#   '$4,878,600'],
#  ['Jarrett Allen',
#   'BRK',
#   '$2,376,840',
#   '$3,909,902',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$6,286,742'],
#  ['Pascal Siakam',
#   'TOR',
#   '$2,351,839',
#   '$29,000,000',
#   '$31,320,000',
#   '$33,640,000',
#   '$35,960,000',
#   '',
#   '1st Round pick',
#   '$132,271,839'],
#  ['Skal Labissière',
#   'POR',
#   '$2,338,847',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '1st Round pick',
#   '$2,338,847'],
#  ['Chandler Hutchison',
#   'CHI',
#   '$2,332,320',
#   '$2,443,440',
#   '$4,019,459',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$4,775,760'],
#  ['Patrick Patterson',
#   'LAC',
#   '$2,331,593',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$2,331,593'],
#  ['Dejounte Murray',
#   'SAS',
#   '$2,321,735',
#   '$14,285,714',
#   '$15,428,571',
#   '$16,571,429',
#   '$17,714,286',
#   '',
#   '1st Round pick',
#   '$66,321,735'],
#  ['Isaiah Thomas', 'WAS', '$2,320,044', '', '', '', '', '', '', '$2,320,044'],
#  ['Alec Burks',
#   'GSW',
#   '$2,320,044',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$2,320,044'],
#  [],
#  [],
#  ['Damian Jones',
#   'ATL',
#   '$2,305,057',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '1st Round pick',
#   '$2,305,057'],
#  ['Darius Bazley',
#   'OKC',
#   '$2,284,800',
#   '$2,399,160',
#   '$2,513,040',
#   '$4,264,629',
#   '',
#   '',
#   '1st Round Pick',
#   '$4,683,960'],
#  ['OG Anunoby',
#   'TOR',
#   '$2,281,800',
#   '$3,872,215',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$6,154,015'],
#  ['Ante Žižić',
#   'CLE',
#   '$2,281,800',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$2,281,800'],
#  ['Monta Ellis',
#   'IND',
#   '$2,245,400',
#   '$2,245,400',
#   '$2,245,400',
#   '',
#   '',
#   '',
#   '',
#   '$6,736,200'],
#  ['Aaron Holiday',
#   'IND',
#   '$2,239,200',
#   '$2,345,640',
#   '$3,980,551',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$4,584,840'],
#  ['Luke Kornet',
#   'CHI',
#   '$2,195,122',
#   '$2,304,878',
#   '',
#   '',
#   '',
#   '',
#   'Room Exception',
#   '$4,500,000'],
#  ['Ty Jerome',
#   'PHO',
#   '$2,193,480',
#   '$2,303,040',
#   '$2,412,840',
#   '$4,220,057',
#   '',
#   '',
#   '1st Round Pick',
#   '$4,496,520'],
#  ['Willie Cauley-Stein',
#   'GSW',
#   '$2,177,483',
#   '$2,286,357',
#   '',
#   '',
#   '',
#   '',
#   'MLE',
#   '$2,177,483'],
#  ['Austin Rivers',
#   'HOU',
#   '$2,174,318',
#   '$2,369,663',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$2,174,318'],
#  ['Carmelo Anthony', 'POR', '$2,159,029', '', '', '', '', '', '', ''],
#  ['Anfernee Simons',
#   'POR',
#   '$2,149,560',
#   '$2,252,040',
#   '$3,938,818',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$4,401,600'],
#  ['Matt Barnes', 'SAC', '$2,133,541', '', '', '', '', '', '', '$2,133,541'],
#  ['Nassir Little',
#   'POR',
#   '$2,105,520',
#   '$2,210,640',
#   '$2,316,240',
#   '$4,171,548',
#   '',
#   '',
#   '1st Round Pick',
#   '$4,316,160'],
#  ['Torrey Craig',
#   'DEN',
#   '$2,100,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$2,100,000'],
#  ['Moritz Wagner',
#   'WAS',
#   '$2,063,520',
#   '$2,161,920',
#   '$3,893,618',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$4,225,440'],
#  ['Dylan Windler',
#   'CLE',
#   '$2,035,800',
#   '$2,137,440',
#   '$2,239,200',
#   '$4,037,278',
#   '',
#   '',
#   '1st Round Pick',
#   '$4,173,240'],
#  ['Caleb Swanigan',
#   'SAC',
#   '$2,033,160',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$2,033,160'],
#  ['Iman Shumpert', 'BRK', '$2,031,677', '', '', '', '', '', '', ''],
#  ["Kyle O'Quinn",
#   'PHI',
#   '$2,028,594',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$2,028,594'],
#  [],
#  [],
#  ['Michael Carter-Williams',
#   'ORL',
#   '$2,028,594',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$2,028,594'],
#  ['Mike Muscala',
#   'OKC',
#   '$2,028,594',
#   '$2,283,034',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$2,028,594'],
#  ['Nerlens Noel',
#   'OKC',
#   '$2,028,594',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$2,028,594'],
#  ['Troy Daniels',
#   'LAL',
#   '$2,028,594',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$2,028,594'],
#  ['Trey Burke',
#   'PHI',
#   '$2,028,594',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$810,000'],
#  ['Spencer Hawes', 'MIL', '$2,007,058', '', '', '', '', '', '', '$2,007,058'],
#  ['Edmond Sumner',
#   'IND',
#   '$2,000,000',
#   '$2,160,000',
#   '$2,320,000',
#   '',
#   '',
#   '',
#   '',
#   '$4,160,000'],
#  ['Noah Vonleh', 'MIN', '$2,000,000', '', '', '', '', '', 'MLE', '$2,000,000'],
#  ['Avery Bradley', 'MEM', '$2,000,000', '', '', '', '', '', '', '$2,000,000'],
#  ['Landry Shamet',
#   'LAC',
#   '$1,995,120',
#   '$2,090,040',
#   '$3,768,342',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$4,085,160'],
#  ['Mfiondu Kabengele',
#   'LAC',
#   '$1,977,000',
#   '$2,075,880',
#   '$2,174,880',
#   '$3,923,484',
#   '',
#   '',
#   '1st Round Pick',
#   '$4,052,880'],
#  ['Kyle Kuzma',
#   'LAL',
#   '$1,974,600',
#   '$3,562,178',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$5,536,778'],
#  ['Jordan Poole',
#   'GSW',
#   '$1,964,760',
#   '$2,063,280',
#   '$2,161,440',
#   '$3,901,399',
#   '',
#   '',
#   '1st Round Pick',
#   '$4,028,040'],
#  ['Tony Bradley',
#   'UTA',
#   '$1,962,360',
#   '$3,542,060',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$5,504,420'],
#  ['Keldon Johnson',
#   'SAS',
#   '$1,950,600',
#   '$2,048,040',
#   '$2,145,720',
#   '$3,873,025',
#   '',
#   '',
#   '1st Round Pick',
#   '$3,998,640'],
#  ['Derrick White',
#   'SAS',
#   '$1,948,080',
#   '$3,516,284',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$5,464,364'],
#  ['Robert Williams',
#   'BOS',
#   '$1,937,520',
#   '$2,029,920',
#   '$3,661,976',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$3,967,440'],
#  ['Josh Hart',
#   'NOP',
#   '$1,934,160',
#   '$3,491,159',
#   '',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$5,425,319'],
#  ['Jacob Evans',
#   'GSW',
#   '$1,925,880',
#   '$2,017,320',
#   '$3,641,263',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$3,943,200'],
#  ['Anderson Varejão',
#   'POR',
#   '$1,913,345',
#   '$1,913,345',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$3,826,690'],
#  [],
#  [],
#  ['Džanan Musa',
#   'BRK',
#   '$1,911,600',
#   '$2,002,800',
#   '$3,615,054',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$3,914,400'],
#  ['Omari Spellman',
#   'GSW',
#   '$1,897,800',
#   '$1,988,280',
#   '$3,588,845',
#   '',
#   '',
#   '',
#   '1st Round Pick',
#   '$3,886,080'],
#  ['James Ennis',
#   'PHI',
#   '$1,882,867',
#   '$2,071,978',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$1,882,867'],
#  ['Shabazz Napier',
#   'MIN',
#   '$1,882,867',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$1,882,867'],
#  ['Glenn Robinson',
#   'GSW',
#   '$1,882,867',
#   '$2,071,978',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$1,882,867'],
#  ['Tim Frazier', 'DET', '$1,882,867', '', '', '', '', '', '', '$1,882,867'],
#  ['Ben McLemore',
#   'HOU',
#   '$1,882,867',
#   '$2,130,023',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$500,000'],
#  ['Larry Sanders',
#   'MIL',
#   '$1,865,547',
#   '$1,865,547',
#   '$1,865,547',
#   '',
#   '',
#   '',
#   '',
#   '$5,596,641'],
#  ['Bruno Caboclo', 'MEM', '$1,845,301', '', '', '', '', '', '', '$300,000'],
#  ['Mario Hezonja',
#   'POR',
#   '$1,737,145',
#   '$1,882,867',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$3,620,012'],
#  ['Emmanuel Mudiay',
#   'UTA',
#   '$1,737,145',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$1,737,145'],
#  ['Raul Neto',
#   'PHI',
#   '$1,737,145',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$1,737,145'],
#  ['JaKarr Sampson',
#   'IND',
#   '$1,737,145',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$1,737,145'],
#  ['Pat Connaughton',
#   'MIL',
#   '$1,723,050',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$1,723,050'],
#  ['Jahlil Okafor',
#   'NOP',
#   '$1,702,486',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$54,323'],
#  ['Rodions Kurucs',
#   'BRK',
#   '$1,699,236',
#   '$1,780,152',
#   '$1,861,068',
#   '',
#   '',
#   '',
#   '',
#   '$3,479,388'],
#  ['Jonah Bolden',
#   'PHI',
#   '$1,698,450',
#   '$1,766,550',
#   '$1,845,000',
#   '',
#   '',
#   '',
#   '',
#   '$1,698,450'],
#  ['Cheick Diallo',
#   'PHO',
#   '$1,678,854',
#   '$1,824,003',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$1,678,854'],
#  ['Treveon Graham',
#   'MIN',
#   '$1,678,854',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$1,678,854'],
#  ['David Nwaba',
#   'BRK',
#   '$1,678,854',
#   '$1,824,003',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$1,678,854'],
#  [],
#  [],
#  ['Dragan Bender',
#   'MIL',
#   '$1,678,854',
#   '$1,824,003',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$600,000'],
#  ['Marquese Chriss', 'GSW', '$1,678,854', '', '', '', '', '', '', ''],
#  ['Willy Hernangómez',
#   'CHO',
#   '$1,676,735',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$1,676,735'],
#  ['Derrick Jones',
#   'MIA',
#   '$1,645,357',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$1,645,357'],
#  ['Christian Wood',
#   'DET',
#   '$1,645,357',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$822,679'],
#  ['Jordan McRae', 'WAS', '$1,645,357', '', '', '', '', '', '', '$600,000'],
#  ['Georges Niang', 'UTA', '$1,645,357', '$1,783,557', '', '', '', '', '', ''],
#  ['Furkan Korkmaz',
#   'PHI',
#   '$1,620,564',
#   '$1,762,796',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$1,620,564'],
#  ['Jordan Bell',
#   'MIN',
#   '$1,620,564',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$1,620,564'],
#  ['Justin Patton',
#   'OKC',
#   '$1,620,564',
#   '$1,762,796',
#   '$1,910,860',
#   '',
#   '',
#   '',
#   '',
#   '$700,000'],
#  ['Wesley Iwundu', 'ORL', '$1,618,520', '', '', '', '', '', '', '$1,618,520'],
#  ['Abdel Nader',
#   'OKC',
#   '$1,618,520',
#   '$1,752,950',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$1,618,520'],
#  ['Damyean Dotson',
#   'NYK',
#   '$1,618,520',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$1,618,520'],
#  ['Frank Jackson',
#   'NOP',
#   '$1,618,520',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'MLE',
#   '$1,618,520'],
#  ['Sterling Brown',
#   'MIL',
#   '$1,618,520',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'MLE',
#   '$1,618,520'],
#  ['Dillon Brooks',
#   'MEM',
#   '$1,618,520',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'MLE',
#   '$1,618,520'],
#  ['Dwayne Bacon',
#   'CHO',
#   '$1,618,520',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'MLE',
#   '$1,618,520'],
#  ['Semi Ojeleye',
#   'BOS',
#   '$1,618,520',
#   '$1,752,950',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$1,618,520'],
#  ["Royce O'Neale", 'UTA', '$1,618,520', '', '', '', '', '', '', ''],
#  ['Chris Boucher', 'TOR', '$1,588,231', '', '', '', '', '', '', '$1,588,231'],
#  [],
#  [],
#  ['Malcolm Miller', 'TOR', '$1,588,231', '', '', '', '', '', '', '$1,588,231'],
#  ['Monte Morris',
#   'DEN',
#   '$1,588,231',
#   '$1,663,861',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$1,588,231'],
#  ['Alfonzo McKinnie', 'CLE', '$1,588,231', '', '', '', '', '', '', ''],
#  ['Tyrone Wallace', 'ATL', '$1,588,231', '', '', '', '', '', '', ''],
#  ['Mitchell Robinson',
#   'NYK',
#   '$1,559,712',
#   '$1,663,861',
#   '$1,802,057',
#   '',
#   '',
#   '',
#   'MLE',
#   '$1,559,712'],
#  ['Vlatko Čančar',
#   'DEN',
#   '$1,517,981',
#   '$898,310',
#   '$1,782,621',
#   '',
#   '',
#   '',
#   'MLE',
#   '$2,416,291'],
#  ['Isaiah Roby',
#   'DAL',
#   '$1,500,000',
#   '$1,517,981',
#   '$1,782,621',
#   '$1,930,681',
#   '',
#   '',
#   'MLE',
#   '$3,017,981'],
#  ['Nigel Williams-Goss',
#   'UTA',
#   '$1,500,000',
#   '$1,517,981',
#   '$1,782,621',
#   '',
#   '',
#   '',
#   '',
#   '$1,500,000'],
#  ['J.R. Smith',
#   'CLE',
#   '$1,456,667',
#   '$1,456,667',
#   '$1,456,666',
#   '',
#   '',
#   '',
#   '',
#   '$4,370,000'],
#  ['Shake Milton',
#   'PHI',
#   '$1,445,697',
#   '$1,701,593',
#   '$1,846,738',
#   '$1,997,718',
#   '',
#   '',
#   'Two-Way Contract',
#   '$4,994,028'],
#  ['Thanasis Antetokounmpo',
#   'MIL',
#   '$1,445,697',
#   '$1,701,593',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$3,147,290'],
#  ['Theo Pinson',
#   'BRK',
#   '$1,445,697',
#   '$1,701,593',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$1,445,697'],
#  ['Brad Wanamaker',
#   'BOS',
#   '$1,445,697',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$1,445,697'],
#  ['Derrick Walton', 'LAC', '$1,445,697', '', '', '', '', '', '', ''],
#  ['Ryan Broekhoff', 'DAL', '$1,443,842', '', '', '', '', '', '', '$1,443,842'],
#  ['Gary Trent',
#   'POR',
#   '$1,416,852',
#   '$1,663,861',
#   '',
#   '',
#   '',
#   '',
#   'MLE',
#   '$3,080,713'],
#  ['Isaac Bonga',
#   'WAS',
#   '$1,416,852',
#   '$1,663,861',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$1,416,852'],
#  ['Chimezie Metu',
#   'SAS',
#   '$1,416,852',
#   '$1,663,861',
#   '',
#   '',
#   '',
#   '',
#   'MLE',
#   '$1,416,852'],
#  ['Jevon Carter',
#   'PHO',
#   '$1,416,852',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'MInimum Salary',
#   '$1,416,852'],
#  ['Elie Okobo',
#   'PHO',
#   '$1,416,852',
#   '$1,663,861',
#   '$1,802,057',
#   '',
#   '',
#   '',
#   '',
#   '$1,416,852'],
#  [],
#  [],
#  ['Melvin Frazier',
#   'ORL',
#   '$1,416,852',
#   '$1,663,861',
#   '',
#   '',
#   '',
#   '',
#   'MLE',
#   '$1,416,852'],
#  ['Deonte Burton', 'OKC', '$1,416,852', '', '', '', '', '', '', '$1,416,852'],
#  ['Hamidou Diallo',
#   'OKC',
#   '$1,416,852',
#   '$1,663,861',
#   '',
#   '',
#   '',
#   '',
#   'MLE',
#   '$1,416,852'],
#  ['Kenrich Williams',
#   'NOP',
#   '$1,416,852',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$1,416,852'],
#  ['Keita Bates-Diop',
#   'MIN',
#   '$1,416,852',
#   '$1,663,861',
#   '',
#   '',
#   '',
#   '',
#   'MLE',
#   '$1,416,852'],
#  ['Duncan Robinson',
#   'MIA',
#   '$1,416,852',
#   '$1,663,861',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$1,416,852'],
#  ["De'Anthony Melton",
#   'MEM',
#   '$1,416,852',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$1,416,852'],
#  ['Alize Johnson',
#   'IND',
#   '$1,416,852',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$1,416,852'],
#  ['Bruce Brown',
#   'DET',
#   '$1,416,852',
#   '$1,663,861',
#   '',
#   '',
#   '',
#   '',
#   'MLE',
#   '$1,416,852'],
#  ['Sviatoslav Mykhailiuk',
#   'DET',
#   '$1,416,852',
#   '$1,663,861',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$1,416,852'],
#  ['Jarred Vanderbilt',
#   'DEN',
#   '$1,416,852',
#   '$1,663,861',
#   '',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$1,416,852'],
#  ["Devonte' Graham",
#   'CHO',
#   '$1,416,852',
#   '$1,663,861',
#   '',
#   '',
#   '',
#   '',
#   'MLE',
#   '$1,416,852'],
#  ['Isaiah Hartenstein',
#   'HOU',
#   '$1,416,852',
#   '$1,663,861',
#   '',
#   '',
#   '',
#   '',
#   'MLE',
#   '$708,426'],
#  ['Gary Clark',
#   'HOU',
#   '$1,416,852',
#   '$1,663,861',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$708,426'],
#  ['Kendrick Nunn',
#   'MIA',
#   '$1,416,852',
#   '$1,663,861',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$450,000'],
#  ['Jalen Brunson',
#   'DAL',
#   '$1,416,582',
#   '$1,663,861',
#   '$1,802,057',
#   '',
#   '',
#   '',
#   'Cap Space',
#   '$3,080,443'],
#  ['Bruno Fernando',
#   'ATL',
#   '$1,400,000',
#   '$1,517,981',
#   '$1,782,621',
#   '',
#   '',
#   '',
#   '',
#   '$4,700,602'],
#  ['Jaylen Nowell',
#   'MIN',
#   '$1,400,000',
#   '$1,517,981',
#   '$1,782,621',
#   '$1,930,681',
#   '',
#   '',
#   'MLE',
#   '$1,400,000'],
#  ['Amile Jefferson',
#   'ORL',
#   '$1,355,851',
#   '$1,701,593',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Kevin Porter',
#   'CLE',
#   '$1,290,960',
#   '$2,033,160',
#   '$2,130,240',
#   '$3,845,083',
#   '',
#   '',
#   '1st Round Pick',
#   '$3,324,120'],
#  [],
#  [],
#  ['Carsen Edwards',
#   'BOS',
#   '$1,200,000',
#   '$1,517,981',
#   '$1,782,621',
#   '$1,930,681',
#   '',
#   '',
#   '',
#   '$4,500,602'],
#  ['Cody Martin',
#   'CHO',
#   '$1,173,310',
#   '$1,517,981',
#   '$1,782,621',
#   '',
#   '',
#   '',
#   'MLE',
#   '$4,473,912'],
#  ['George Hill', 'MIL', '$1,000,000', '', '', '', '', '', '', '$21,000,000'],
#  ['Terance Mann',
#   'LAC',
#   '$1,000,000',
#   '$1,517,984',
#   '$1,782,621',
#   '$1,930,681',
#   '',
#   '',
#   '',
#   '$2,517,984'],
#  ['Jonathon Simmons',
#   'WAS',
#   '$1,000,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$1,000,000'],
#  ['Justin Hamilton',
#   'TOR',
#   '$1,000,000',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$1,000,000'],
#  ['Kyle Singler',
#   'OKC',
#   '$999,200',
#   '$999,200',
#   '$999,200',
#   '$999,200',
#   '',
#   '',
#   '',
#   '$3,996,800'],
#  ['Admiral Schofield',
#   'WAS',
#   '$898,310',
#   '$1,517,981',
#   '$1,782,621',
#   '',
#   '',
#   '',
#   'MLE',
#   '$4,198,912'],
#  ['KZ Okpala',
#   'MIA',
#   '$898,310',
#   '$1,517,981',
#   '$1,782,621',
#   '',
#   '',
#   '',
#   'MLE',
#   '$4,198,912'],
#  ['Eric Paschall',
#   'GSW',
#   '$898,310',
#   '$1,517,981',
#   '$1,782,621',
#   '',
#   '',
#   '',
#   'MLE',
#   '$4,198,912'],
#  ['Nicolas Claxton',
#   'BRK',
#   '$898,310',
#   '$1,517,981',
#   '$1,782,621',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$4,198,912'],
#  ['Justin James',
#   'SAC',
#   '$898,310',
#   '$1,517,981',
#   '$1,782,621',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$2,416,291'],
#  ['Jalen Lecque',
#   'PHO',
#   '$898,310',
#   '$1,517,981',
#   '$1,782,621',
#   '$1,930,681',
#   '',
#   '',
#   '',
#   '$2,416,291'],
#  ['Ignas Brazdeikis',
#   'NYK',
#   '$898,310',
#   '$1,517,981',
#   '$1,782,621',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$2,416,291'],
#  ['Talen Horton-Tucker',
#   'LAL',
#   '$898,310',
#   '$1,517,981',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$2,416,291'],
#  ['Daniel Gafford',
#   'CHI',
#   '$898,310',
#   '$1,517,981',
#   '$1,782,621',
#   '$1,930,681',
#   '',
#   '',
#   'Minimum Salary',
#   '$2,416,291'],
#  ['Alen Smailagić',
#   'GSW',
#   '$898,310',
#   '$1,517,981',
#   '$1,782,621',
#   '$1,930,681',
#   '',
#   '',
#   'MLE',
#   '$2,415,891'],
#  ['Matt Thomas',
#   'TOR',
#   '$898,310',
#   '$1,517,981',
#   '$1,782,621',
#   '',
#   '',
#   '',
#   'MLE',
#   '$1,623,310'],
#  ['Miye Oni',
#   'UTA',
#   '$898,310',
#   '$1,517,981',
#   '$1,782,621',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$898,310'],
#  ['Terence Davis',
#   'TOR',
#   '$898,310',
#   '$1,517,981',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$898,310'],
#  [],
#  [],
#  ['Naz Reid',
#   'MIN',
#   '$898,310',
#   '$1,517,981',
#   '$1,782,621',
#   '$1,930,681',
#   '',
#   '',
#   'MLE',
#   '$898,310'],
#  ['Dewan Hernandez',
#   'TOR',
#   '$898,310',
#   '$1,517,981',
#   '$1,782,621',
#   '',
#   '',
#   '',
#   'MLE',
#   '$500,000'],
#  ['Justin Robinson',
#   'WAS',
#   '$898,310',
#   '$1,517,981',
#   '$1,782,621',
#   '',
#   '',
#   '',
#   'MLE',
#   '$250,000'],
#  ['Shaquille Harrison', 'CHI', '$898,310', '', '', '', '', '', '', '$175,000'],
#  ['Javonte Green',
#   'BOS',
#   '$898,310',
#   '$1,517,981',
#   '',
#   '',
#   '',
#   '',
#   'Minimum Salary',
#   '$100,000'],
#  ['Caleb Martin',
#   'CHO',
#   '$898,310',
#   '$1,517,981',
#   '$1,782,621',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Wenyen Gabriel', 'SAC', '$898,310', '', '', '', '', '', '', ''],
#  ['Khyri Thomas',
#   'DET',
#   '$838,464',
#   '$1,663,861',
#   '',
#   '',
#   '',
#   '',
#   'MLE',
#   '$838,464'],
#  ['Patrick Patterson',
#   'OKC',
#   '$737,067',
#   '$737,067',
#   '$737,066',
#   '',
#   '',
#   '',
#   '',
#   '$2,211,200'],
#  ['Cole Aldrich',
#   'MIN',
#   '$685,340',
#   '$685,340',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$1,370,680'],
#  ['Shaun Livingston',
#   'GSW',
#   '$666,667',
#   '$666,667',
#   '$666,666',
#   '',
#   '',
#   '',
#   '',
#   '$2,666,666'],
#  ['Ryan Anderson', 'HOU', '$500,000', '', '', '', '', '', '', '$500,000'],
#  ['Dakari Johnson',
#   'MEM',
#   '$459,414',
#   '$459,414',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$918,828'],
#  ['Max Strus', 'BOS', '$415,414', '', '', '', '', '', '', '$415,414'],
#  ['Ivan Rabb', 'MEM', '$371,758', '', '', '', '', '', '', '$371,758'],
#  ['A.J. Hammons',
#   'MIA',
#   '$350,087',
#   '$350,087',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '$700,174'],
#  ['Festus Ezeli', 'POR', '$333,333', '', '', '', '', '', '', '$333,333'],
#  ['C.J. Watson', 'ORL', '$333,333', '', '', '', '', '', '', '$333,333'],
#  ['Stanton Kidd', 'UTA', '$250,000', '', '', '', '', '', '', '$250,000'],
#  ['Joe Johnson', 'DET', '$220,000', '', '', '', '', '', '', '$220,000'],
#  [],
#  [],
#  ['Jemerrio Jones', 'WAS', '$199,000', '', '', '', '', '', '', '$199,000'],
#  ['Cameron Payne', 'TOR', '$150,000', '', '', '', '', '', '', '$150,000'],
#  ['Troy Williams',
#   'HOU',
#   '$122,741',
#   '$122,741',
#   '$122,741',
#   '$122,741',
#   '',
#   '',
#   '',
#   '$490,964'],
#  ['Yante Maten', 'MIA', '$100,000', '', '', '', '', '', '', '$100,000'],
#  ['Jaylen Adams', 'ATL', '$100,000', '', '', '', '', '', '', '$100,000'],
#  ['Demetrius Jackson',
#   'BOS',
#   '$92,857',
#   '$92,857',
#   '$92,857',
#   '$92,857',
#   '$92,857',
#   '',
#   '',
#   '$464,285'],
#  ['William Howard', 'UTA', '$50,000', '', '', '', '', '', '', '$50,000'],
#  ['Isaiah Taylor', 'TOR', '$50,000', '', '', '', '', '', '', '$50,000'],
#  ['Tyler Lydon', 'SAC', '$50,000', '', '', '', '', '', '', '$50,000'],
#  ['Hollis Thompson', 'SAC', '$50,000', '', '', '', '', '', '', '$50,000'],
#  ['Tyler Ulis', 'SAC', '$50,000', '', '', '', '', '', '', '$50,000']]
